# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %config InlineBackend.figure_format = 'svg'

# %%
df = pd.read_csv('imdb_preprocessed.csv', sep=',')

# %%
df.head()
# Out:
#                Series_Title  Released_Year  ... No_of_Votes        Gross
# 0  The Shawshank Redemption         1994.0  ...     2343110   28341469.0
# 1             The Godfather         1972.0  ...     1620367  134966411.0
# 2           The Dark Knight         2008.0  ...     2303232  534858444.0
# 3    The Godfather: Part II         1974.0  ...     1129952   57300000.0
# 4              12 Angry Men         1957.0  ...      689845    4360000.0
#
# [5 rows x 15 columns]

# %%
sns.pairplot(df)

# %%
sns.displot(df['Meta_score'][pd.notnull(df['Meta_score'])])

# %%
df['IMDB_Rating'].describe()
# Out:
# count    1000.000000
# mean        7.949300
# std         0.275491
# min         7.600000
# 25%         7.700000
# 50%         7.900000
# 75%         8.100000
# max         9.300000
# Name: IMDB_Rating, dtype: float64

# %%
sns.displot(df['IMDB_Rating'][pd.notnull(df['IMDB_Rating'])],kde=False, bins=50)
